# %% [markdown]
# ## 1. Data Loading and Inspection

# %%
# Cell 1: Import Libraries and Load Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Settings for better visualizations
sns.set_style("whitegrid")

# Load the dataset
df = pd.read_csv('Leads.csv')

# Display the first few rows
print("First 5 rows of the dataset:")
display(df.head())

# Get a concise summary of the dataframe
print("\nDataset Info:")
df.info()

# Get summary statistics for numerical columns
print("\nSummary Statistics:")
display(df.describe())
# Out:
# First 5 rows of the dataset:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# ## 2. Focused Exploratory Data Analysis

# %%
# Cell 2: EDA - Time Spent on Website vs. Conversion
plt.figure(figsize=(8, 5))
sns.boxplot(y='Total Time Spent on Website', x='Converted', data=df)
plt.title('Total Time Spent on Website vs. Conversion')
plt.ylabel('Total Time Spent on Website (seconds)')
plt.xlabel('Conversion Status (1: Converted, 0: Not Converted)')
plt.savefig('time_vs_conversion.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Cell 3: EDA - Lead Origin vs. Conversion (with saving)
plt.figure(figsize=(12, 6))
sns.countplot(x='Lead Origin', hue='Converted', data=df)
plt.title('Lead Origin vs. Conversion Status')
plt.xticks(rotation=45)

# This is the new line that saves the plot
plt.savefig('origin_vs_conversion.png', dpi=300, bbox_inches='tight') 

plt.show()

# %%
# Cell 4: EDA - Occupation vs. Conversion (with saving)

# Replace 'Select' with NaN (Not a Number) to represent it as a missing value
df['What is your current occupation'].replace('Select', np.nan, inplace=True)

# Create the plot
plt.figure(figsize=(12, 6))
sns.countplot(x='What is your current occupation', hue='Converted', data=df)
plt.title('Occupation vs. Conversion Status')
plt.xticks(rotation=60) # Increased rotation for better readability

# Save the figure
plt.savefig('occupation_vs_conversion.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/pw/jsy_lyp56lbb80cjv0hcmghr0000gn/T/ipykernel_44341/2557133364.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['What is your current occupation'].replace('Select', np.nan, inplace=True)

# %% [markdown]
# ### EDA Summary & Modeling Plan
#
# Based on the initial exploration:
# -   **Total Time Spent on Website:** This is a very strong predictor. The more time a user spends, the more likely they are to convert.
# -   **Lead Origin:** Leads from "Lead Add Form" and "Lead Import" have a much higher conversion rate.
# -   **Occupation:** "Working Professional" is a very strong positive indicator for conversion.
#
# **Plan:**
# 1.  Clean the data by handling missing values and converting categorical features.
# 2.  Split the data into training and testing sets.
# 3.  Build and compare Logistic Regression, Random Forest, and XGBoost models.
# 4.  Evaluate models using AUC-ROC, Accuracy, and Precision.

# %% [markdown]
# ## 3. Modeling

# %% [markdown]
# ## 3.1 Preprocessing

# %%
# Cell 5: Data Cleaning and Preprocessing
from sklearn.model_selection import train_test_split

# --- Data Cleaning ---

# For this sprint, we'll drop columns that are not immediately useful, are redundant, or have too many unique values to encode easily.
cols_to_drop = ['Prospect ID', 'Lead Quality', 'Asymmetrique Activity Index', 
                'Asymmetrique Profile Index', 'Asymmetrique Activity Score', 'Asymmetrique Profile Score',
                'Tags', 'Last Notable Activity', 'Last Activity', 'Lead Profile']

df_clean = df.drop(cols_to_drop, axis=1)

# For speed, we will drop rows with any remaining missing values.
# A more advanced approach would be to impute them, but this is faster for our sprint.
df_clean.dropna(inplace=True)

# --- Preprocessing ---

# Convert all categorical columns to numerical using one-hot encoding
categorical_cols = df_clean.select_dtypes(include=['object']).columns
df_final = pd.get_dummies(df_clean, columns=categorical_cols, drop_first=True)

# Separate features (X) and the target variable (y)
X = df_final.drop('Converted', axis=1)
y = df_final['Converted']

# Split data into a training set (70%) and a testing set (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print("Shape of training data (X_train):", X_train.shape)
print("Shape of testing data (X_test):", X_test.shape)
# Out:
# Shape of training data (X_train): (3447, 99)
# Shape of testing data (X_test): (1478, 99)

# %% [markdown]
# ## 3.2 Model Training

# %%
# Cell 6: Model Building and Training
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Initialize the models with settings for reproducibility
log_reg = LogisticRegression(max_iter=1000, random_state=42)
rand_forest = RandomForestClassifier(random_state=42)
xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')

# Train the models on the training data
print("Training Logistic Regression...")
log_reg.fit(X_train, y_train)

print("Training Random Forest...")
rand_forest.fit(X_train, y_train)

print("Training XGBoost...")
xgb.fit(X_train, y_train)

print("\nAll models have been trained successfully! ✅")
# Out:
# Training Logistic Regression...
# /Users/aayushjha/opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Random Forest...
# Training XGBoost...
#
# All models have been trained successfully! ✅
# /Users/aayushjha/opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:41:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# ## 3.3 Evaluation

# %%
# Cell 7: Model Evaluation
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score

# --- Make Predictions ---
# Get class predictions (0 or 1)
y_pred_log_reg = log_reg.predict(X_test)
y_pred_rand_forest = rand_forest.predict(X_test)
y_pred_xgb = xgb.predict(X_test)

# Get prediction probabilities (needed for AUC-ROC)
y_prob_log_reg = log_reg.predict_proba(X_test)[:, 1]
y_prob_rand_forest = rand_forest.predict_proba(X_test)[:, 1]
y_prob_xgb = xgb.predict_proba(X_test)[:, 1]

# --- Calculate Metrics ---
metrics = {
    'Model': ['Logistic Regression', 'Random Forest', 'XGBoost'],
    'AUC-ROC Score': [roc_auc_score(y_test, y_prob_log_reg), 
                      roc_auc_score(y_test, y_prob_rand_forest), 
                      roc_auc_score(y_test, y_prob_xgb)],
    'Accuracy': [accuracy_score(y_test, y_pred_log_reg), 
                 accuracy_score(y_test, y_pred_rand_forest), 
                 accuracy_score(y_test, y_pred_xgb)],
    'Precision': [precision_score(y_test, y_pred_log_reg), 
                  precision_score(y_test, y_pred_rand_forest), 
                  precision_score(y_test, y_pred_xgb)]
}

results_df = pd.DataFrame(metrics).round(3) # Rounding to 3 decimal places
results_df.set_index('Model', inplace=True) # Set Model as the index

print("Model Performance Comparison:")
display(results_df)
# Out:
# Model Performance Comparison:
#                      AUC-ROC Score  Accuracy  Precision
# Model
# Logistic Regression          0.833     0.773      0.775
# Random Forest                0.821     0.772      0.759
# XGBoost                      0.806     0.756      0.735
